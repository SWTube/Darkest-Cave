# %% [markdown]
# # 해당 ipynb 파일은 google colab에서 동작시켜야 합니다
#
#
#
# ## https://research.google.com/colaboratory/
# ## SSH Remote 접속을 코딩할 때마다 해야하는 불편함이 있습니다.
# ## 원격 VS Code에서 코딩하는 파일은 Google Drive에 마운트 됩니다.

# %% [markdown]
# ### 작업 폴더 경로 /content/drive/Shareddrives/SWTube/프로젝트/044. 2021 소융튜브 특성화 프로젝트/데이터 팀/mount_drive/

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### ssh root@숫자.tcp.ngrok.io -p 포트

# %% [markdown]
# ### Linux만 동작하는 것 같음

# %%
# NGROK_TOKEN은 계정마다 다릅니다

NGROK_TOKEN = '1vB5czbzPCnCjznMM8vY7Fuq3Hh_5ABBYLjyAwiU94WBy8a92'
PASSWORD = 'swtube'

# %% [markdown]
# #GPU 확인

# %%
# !nvidia-smi

# %% [markdown]
# #Google Drive 마운트
#
# 왼쪽 폴더 - 구글 드라이브 마운트

# %% [markdown]
# #Colab-SSH로 접속하기

# %%
# Install colab_ssh on google colab
# !pip install colab_ssh --upgrade

# %%
from colab_ssh import launch_ssh

launch_ssh(NGROK_TOKEN, PASSWORD)
# Out:
# ...
# we highly recommend that update your code by following this documentation https://github.com/WassimBenzarti/colab-ssh#getting-started
# Successfully running 0.tcp.ngrok.io:10570
# [Optional] You can also connect with VSCode SSH Remote extension using this configuration:
#
#   Host google_colab_ssh
#     HostName 0.tcp.ngrok.io
#     User root
#     Port 10570
